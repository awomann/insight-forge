# %% [markdown]
# ### Import Data
# Import data loader and load the data.

# %%
import sys
sys.path.append('..')

from src.data_loader import load_sales_data

df = load_sales_data()
df.head()
# Out:
#          Order ID Order Date Region             City       State    Segment  \
# 0  CA-2016-152156 2016-11-08  South        Henderson    Kentucky   Consumer
# 1  CA-2016-152156 2016-11-08  South        Henderson    Kentucky   Consumer
# 2  CA-2016-138688 2016-06-12   West      Los Angeles  California  Corporate
# 3  US-2015-108966 2015-10-11  South  Fort Lauderdale     Florida   Consumer
# 4  US-2015-108966 2015-10-11  South  Fort Lauderdale     Florida   Consumer
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
# 3        Furniture       Tables
# 4  Office Supplies      Storage
#
#                                         Product Name     Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase  261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...  731.9400         3
# 2  Self-Adhesive Address Labels for Typewriters b...   14.6200         2
# ...

# %%
df.tail()
# Out:
#             Order ID Order Date Region         City       State   Segment  \
# 9989  CA-2014-110422 2014-01-21  South        Miami     Florida  Consumer
# 9990  CA-2017-121258 2017-02-26   West   Costa Mesa  California  Consumer
# 9991  CA-2017-121258 2017-02-26   West   Costa Mesa  California  Consumer
# 9992  CA-2017-121258 2017-02-26   West   Costa Mesa  California  Consumer
# 9993  CA-2017-119914 2017-05-04   West  Westminster  California  Consumer
#
#              Category Sub-Category  \
# 9989        Furniture  Furnishings
# 9990        Furniture  Furnishings
# 9991       Technology       Phones
# 9992  Office Supplies        Paper
# 9993  Office Supplies   Appliances
#
#                                            Product Name    Sales  Quantity  \
# 9989                             Ultra Door Pull Handle   25.248         3
# 9990  Tenex B1-RE Series Chair Mats for Low Pile Car...   91.960         2
# 9991                              Aastra 57i VoIP phone  258.576         2
# ...

# %%
df.describe()
# Out:
#                           Order Date         Sales     Quantity     Discount  \
# count                           9994   9994.000000  9994.000000  9994.000000
# mean   2016-04-30 00:07:12.259355648    229.858001     3.789574     0.156203
# min              2014-01-03 00:00:00      0.444000     1.000000     0.000000
# 25%              2015-05-23 00:00:00     17.280000     2.000000     0.000000
# 50%              2016-06-26 00:00:00     54.490000     3.000000     0.200000
# 75%              2017-05-14 00:00:00    209.940000     5.000000     0.200000
# max              2017-12-30 00:00:00  22638.480000    14.000000     0.800000
# std                              NaN    623.245101     2.225110     0.206452
#
#             Profit
# count  9994.000000
# mean     28.656896
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000
# std     234.260108

# %%
df.groupby('Category')['Sales'].describe()

# Technology has massive variance. That $22k order is an outlier pulling everything up. Also notice Office Supplies has the most orders by far (6,026) but the lowest average sale ($119). One more thing worth noticing — Office Supplies has a max of $9,892 which seems oddly high for office supplies. That's probably a bulk order.
# Out:
#                   count        mean          std    min     25%      50%  \
# Category
# Furniture        2121.0  349.834887   503.179145  1.892  47.040  182.220
# Office Supplies  6026.0  119.324101   382.182228  0.444  11.760   27.418
# Technology       1847.0  452.709276  1108.655848  0.990  68.016  166.160
#
#                      75%        max
# Category
# Furniture        435.168   4416.174
# Office Supplies   79.920   9892.740
# Technology       448.534  22638.480

# %%
df.groupby('Category')['Profit'].sum()
# Out:
# Category
# Furniture           18451.2728
# Office Supplies    122490.8008
# Technology         145454.9481
# Name: Profit, dtype: float64

# %%
df.groupby('Category')['Discount'].mean()

# Furniture has the highest average discount AND the lowest profit — that's your culprit. The discounting strategy for Furniture is hurting the business.
# Out:
# Category
# Furniture          0.173923
# Office Supplies    0.157285
# Technology         0.132323
# Name: Discount, dtype: float64

# %%
df.groupby('Region')[['Sales', 'Profit']].sum()

# West leads in both sales and profit.West leads in both sales and profit. Central is interesting — it has decent sales but the lowest profit relative to its sales volume, similar to the Furniture story.
# Out:
#                Sales       Profit
# Region
# Central  501239.8908   39706.3625
# East     678781.2400   91522.7800
# South    391721.9050   46749.4303
# West     725457.8245  108418.4489
